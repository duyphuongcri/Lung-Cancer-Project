# %%
import sys 
sys.path.append("../")
import pydicom
import os, glob
import misc
import numpy as np
from datetime import datetime

# %%
def CalcuateSUV(patientInfor):
    #Method:  SUVbw, SUVlbm or SUVbsa
    #Method='SUVbw';
    Img = np.stack([s.pixel_array for s in patientInfor])
    patientInfor = patientInfor[0]
    
    assert len(patientInfor[0x28, 0x51].value) > 0, 'Corrected Image (0x28,0x51) should contains \
                                                    ATTN and DECAY and Decay Correction (0x0054,0x1102) must be START'
    assert patientInfor[0x54, 0x1102].value == 'START', 'Decay Correction (0x0054,0x1102) must be START'
    assert 'ATTN' and 'DECY' in patientInfor[0x28, 0x51].value, 'Corrected Image (0x0028,0x0051) should contains ATTN and DECAY'
   
    if patientInfor[0x54, 0x1001].value == "BQML": #if Units (0x0054,0x1001) are BQML
        #half life = Radionuclide Half Life (0x0018,0x1075) in Radiopharmaceutical Information Sequence (0x0054,0x0016)
        T_half = 109.8*60 #patient_PET[0][0x54, 0x16][0][0x18, 0x1075].value #half life of FDG

        
        AcquisitionDateandTime = str(int(float(patientInfor.AcquisitionDate + patientInfor.AcquisitionTime)))
        SeriesDateandTime = str(int(float(patientInfor.SeriesDate + patientInfor.SeriesTime)))

        """
        if Series Date (0x0008,0x0021) and Time (0x0008,0x0031) 
        are not after Acquisition Date (0x0008,0x0022) and Time (0x0008,0x0032) 
         """
        if float(SeriesDateandTime) <= float(AcquisitionDateandTime):        
            ScanDateandTime = datetime.strptime(SeriesDateandTime, "%Y%m%d%H%M%S")  #scan Date and Time = Series Date and Time
        else: 
            """may be post-processed series in which Series Date and Time are date of series creation unrelated to acquisition""" 
            if  patientInfor[0x09, 0x10].value == 'GEMS_PETD_01':#if  GE private scan Date and Time (0x0009,0x100d,¡°GEMS_PETD_01¡±) present {
                ScanDateandTime = patientInfor[0x09, 0x100d].value #scan Date and Time = GE private scan Date and Time (0x0009,0x100d,¡°GEMS_PETD_01¡±)        
            else: 
                """
                % // else may be Siemens series with altered Series Date and Time
                % // either check earliest of all images in series (for all bed positions) (wrong for case of PETsyngo 3.x multi-injection)
                % scan Date and Time = earliest Acquisition Date (0x0008,0x0022) and Time (0x0008,0x0032)  in all images of series
                % or
                % // back compute from center (average count rate ) of time window for bed position (frame) in series (reliable in all cases)
                % // Acquisition Date (0x0008,0x0022) and Time (0x0008,0x0032) are the start of the bed position (frame)
                % // Frame Reference Time (0x0054,0x1300) is the offset (ms) from the scan Date and Time we want to the average count rate time
                % if  (Frame Reference Time (0x0054,0x1300) > 0 && Actual Frame Duration (0018,1242) > 0) {
                % frame duration = Actual Frame Duration (0018,1242) / 1000		// DICOM is in ms; want seconds
                % decay constant = ln(2) /  half life
                % decay during frame = decay constant * frame duration
                % average count rate time within frame = 1/decay constant * ln(decay during frame / (1 ¨C exp(-decay during frame)))
                % scan Date and Time = Acquisition Date (0x0008,0x0022) and Time (0x0008,0x0032)
                % -	Frame Reference Time (0x0054,0x1300) /1000 + average count rate time within frame
                % 
                """
                pass
            
        #start Time = Radiopharmaceutical Start Time (0x0018,0x1072) in Radiopharmaceutical Information Sequence (0x0054,0x0016) 
        startTime = patientInfor[0x54, 0x16][0][0x18, 0x1072].value
        StartDateandTime = str(int(float(patientInfor.SeriesDate + startTime)))
        StartDateandTime = datetime.strptime(StartDateandTime, "%Y%m%d%H%M%S")
        decayTime = ScanDateandTime - StartDateandTime 
        total_seconds = decayTime.seconds # decay Time = scan Time ¨C start Time 	// seconds
        #injected Dose = Radionuclide Total Dose (0x0018,0x1074) in Radiopharmaceutical Information Sequence (0x0054,0x0016)	// Bq
        injectedDose = float(patientInfor[0x54, 0x16][0][0x18, 0x1074].value)
        print(injectedDose)
        decayedDose = injectedDose*np.exp(total_seconds*np.log(2)/T_half)    #injectedDose * pow (2, -decayTime / T_half);
        weight = float(patientInfor[0x10, 0x1030].value)
        SUVbwScaleFactor = (weight * 1000 / decayedDose)
   
    elif patientInfor[0x54, 0x1001].value == 'CNTS':# if Units (0x0054,0x1001) are CNTS
        """        
        Philips private scale factor (0x7053,0x1000,¡° Philips PET Private Group¡±)
        if (0x7053,0x1000) not present, but (0x7053,0x1009) is present, then (0x7053,0x1009) * Rescale Slope
        scales pixels to Bq/ml, and proceed as if Units are BQML
        """

        if len(patientInfor[0x7053, 0x1000].value) == 0:
            RescaleSlope=patientInfor.RescaleSlope; #Rescale Slope (0x0028,0x1053)
            SUVbwScaleFactor = patientInfor[0x7053, 0x1009].value * RescaleSlope;
        else:
            SUVbwScaleFactor = patientInfor[0x7053, 0x1000].value 
    elif patientInfor[0x54, 0x1001].value == 'GML': #  if Units (0x0054,0x1001) are GML    
        SUVbwScaleFactor = 1.0 #assumes that GML indicates SUVbw instead of SUVlbm

    RescaleIntercept = patientInfor[0x28, 0x1052].value
    RescaleSlope =  patientInfor[0x28, 0x1053].value
    print(RescaleIntercept, RescaleSlope, SUVbwScaleFactor)
    SUV = (Img + RescaleIntercept )*RescaleSlope*SUVbwScaleFactor
    return SUV

# %%
Path = "D:\\LungCancer\\2021-lung-cancer\Data_label_CT_PET_n_256\\AIDATA_PET_20201105(n=246)_20210202+÷-ñ\\"
can_not_cal_suv = []
for dirName, subdirList, fileList in os.walk(Path):
    if (len(fileList) > 1) :
#         if 'LC00588' not in dirName:
#             continue
        patient_PET = misc.load_scan(dirName)
        print(dirName)
        print(patient_PET[0])
        try:
            pet_nor = CalcuateSUV(patient_PET)
            print(pet_nor.min(), pet_nor.max())
        except:
            can_not_cal_suv.append(dirName[-7:])
        print()
        break
# Out:
# D:\LungCancer\2021-lung-cancer\Data_label_CT_PET_n_256\AIDATA_PET_20201105(n=246)_20210202+÷-ñ\LC00026
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Positron Emission Tomography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794165.377
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.840.113619.6.379
# (0002, 0013) Implementation Version Name         SH: 'AIA 5.2 (086)'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 446
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0012) Instance Creation Date              DA: '20200511'
# (0008, 0013) Instance Creation Time              TM: '132326'
# (0008, 0016) SOP Class UID                       UI: Positron Emission Tomography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794165.377
# (0008, 0020) Study Date                          DA: '20200511'
# (0008, 0021) Series Date                         DA: '20200511'
# (0008, 0022) Acquisition Date                    DA: '20200511'
# (0008, 0023) Content Date                        DA: '20200511'
# (0008, 0030) Study Time                          TM: '131707'
# (0008, 0031) Series Time                         TM: '132031'
# (0008, 0032) Acquisition Time                    TM: '132031'
# (0008, 0033) Content Time                        TM: '132326'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'PT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'awpc_29779349'
# (0008, 1030) Study Description                   LO: 'Torso PET-CT'
# (0008, 103e) Series Description                  LO: 'Torso_3D_PET'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Discovery ST'
# (0009, 0000) Private Creator                     UL: 2614
# (0009, 0010) Private tag data                    LO: 'GEMS_PETD_01'
# (0009, 100a) [PET scan_id]                       UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.378
# (0009, 100d) [PET scan_datetime]                 DT: '20200511132031.00'
# (0009, 100e) [PET scan_ready]                    DT: '20200511131941.00'
# (0009, 1013) [PET for_identifier]                UI: 1.2.840.113619.2.379.114374074503672.7872.1589332793459.6
# (0009, 1014) [PET landmark_name]                 LO: 'Orbital Meatal Line'
# (0009, 1015) [PET landmark_abbrev]               SH: 'OM'
# (0009, 1016) [PET patient_position]              SL: 0
# (0009, 1017) [PET scan_perspective]              SL: 0
# (0009, 1018) [PET scan_type]                     SL: 0
# (0009, 1019) [PET scan_mode]                     SL: 0
# (0009, 101a) [PET start_condition]               SL: 1
# (0009, 101b) [PET start_cond_data]               SL: 0
# (0009, 101c) [PET sel_stop_cond]                 SL: 1
# (0009, 101d) [PET sel_stop_cond_data]            SL: 0
# (0009, 101e) [PET collect_deadtime]              SL: 1
# (0009, 101f) [PET collect_singles]               SL: 1
# (0009, 1020) [PET collect_countrate]             SL: 0
# (0009, 1021) [PET countrate_period]              SL: 1
# (0009, 1022) [PET delayed_events]                SL: 0
# (0009, 1023) [PET delayed_bias]                  SL: 0
# (0009, 1024) [PET word_size]                     SL: 2
# (0009, 1025) [PET axial_acceptance]              SL: 2
# (0009, 1026) [PET axial_angle_3d]                SL: 23
# (0009, 1027) [PET theta_compression]             SL: 1
# (0009, 1028) [PET axial_compression]             SL: 1
# (0009, 1029) [PET gantry_tilt_angle]             FL: 0.0
# (0009, 102a) [PET collimation]                   SL: 0
# (0009, 102b) [PET scan_fov]                      SL: 70
# (0009, 102c) [PET axial_fov]                     SL: 153
# (0009, 102d) [PET event_separation]              SL: 0
# (0009, 102e) [PET mask_width]                    SL: 0
# (0009, 1034) [PET triggers_acquired]             SL: 0
# (0009, 1035) [PET triggers_rejected]             SL: 0
# (0009, 1036) [PET tracer_name]                   LO: 'FDG -- fluorodeoxyglucose'
# (0009, 1037) [PET batch_description]             LO: ''
# (0009, 1038) [PET tracer_activity]               FL: 410.70001220703125
# (0009, 1039) [PET meas_datetime]                 DT: '20200511121500.00'
# (0009, 103a) [PET pre_inj_volume]                FL: 3.0
# (0009, 103b) [PET admin_datetime]                DT: '20200511121600.00'
# (0009, 103c) [PET post_inj_activity]             FL: 2.5899999141693115
# (0009, 103d) [PET post_inj_datetime]             DT: '20200511121700.00'
# (0009, 103e) [PET radionuclide_name]             SH: '18F'
# (0009, 103f) [PET half_life]                     FL: 6588.0
# (0009, 1040) [PET positron_fraction]             FL: 0.9700000286102295
# (0009, 104d) [PET emission_present]              SL: 0
# (0009, 104e) [PET lower_axial_acc]               SL: 23
# (0009, 104f) [PET upper_axial_acc]               SL: 23
# (0009, 1050) [PET lower_coinc_limit]             SL: 4
# (0009, 1051) [PET upper_coinc_limit]             SL: 4
# (0009, 1052) [PET coinc_delay_offset]            SL: 32
# (0009, 1053) [PET coinc_output_mode]             SL: 800
# (0009, 1054) [PET upper_energy_limit]            SL: 650
# (0009, 1055) [PET lower_energy_limit]            SL: 375
# (0009, 1056) [PET normal_cal_id]                 UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.379
# (0009, 1057) [PET normal_2d_cal_id]              UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.380
# (0009, 1059) [PET wc_cal_id]                     UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.381
# (0009, 105a) [PET derived]                       SL: 0
# (0009, 105c) [PET frame_id]                      UI: ''
# (0009, 105d) [PET scan_id]                       UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.378
# (0009, 105e) [PET exam_id]                       UI: 1.2.840.113619.2.379.114374074503672.7872.1589332793459.4
# (0009, 1062) [PET where_is_frame]                ST: '/petRDFS/OFUVLOAA/XQUJIFVL/PCCOWYAO/SINO0000'
# (0009, 1063) [PET frame_size]                    SL: 0
# (0009, 1064) [PET file_exists]                   SL: 0
# (0009, 1066) [PET table_height]                  FL: 112.5
# (0009, 1067) [PET table_z_position]              FL: 990.0
# (0009, 1068) [PET landmark_datetime]             DT: '20200511132010.00'
# (0009, 1069) [PET slice_count]                   SL: 553
# (0009, 106a) [PET start_location]                FL: -1196.4000244140625
# (0009, 106b) [PET acq_delay]                     SL: 0
# (0009, 106c) [PET acq_start]                     DT: '20200511132031.00'
# (0009, 106d) [PET acq_duration]                  SL: 140
# (0009, 1070) [PET actual_stop_cond]              SL: 0
# (0009, 1071) [PET total_prompts]                 FD: 46809651.0
# (0009, 1072) [PET total_delays]                  FD: 0.0
# (0009, 1073) [PET frame_valid]                   SL: 1
# (0009, 1074) [PET validity_info]                 SL: 255
# (0009, 107c) [PET is_source]                     SL: 0
# (0009, 107d) [PET is_contents]                   SL: 2
# (0009, 107e) [PET is_type]                       SL: 0
# (0009, 107f) [PET is_reference]                  DS: "0.0"
# (0009, 1080) [PET multi_patient]                 SL: 0
# (0009, 1081) [PET number_of_normals]             SL: 0
# (0009, 108b) [PET recon_method]                  SL: 5
# (0009, 108c) [PET attenuation]                   SL: 2
# (0009, 108d) [PET atten_coefficient]             FL: 0.09600000083446503
# (0009, 108e) [PET bp_filter]                     SL: 0
# (0009, 108f) [PET bp_filter_cutoff]              FL: 0.0
# (0009, 1090) [PET bp_filter_order]               SL: 0
# (0009, 1091) [PET bp_center_l]                   FL: 0.0
# (0009, 1092) [PET bp_center_p]                   FL: 0.0
# (0009, 1093) [PET atten_smooth]                  SL: 0
# (0009, 1094) [PET atten_smooth_param]            SL: 0
# (0009, 1095) [PET angle_smooth_param]            SL: 0
# (0009, 1096) [PET wellcountercal_id]             UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.381
# (0009, 1097) [PET trans_scan_id]                 UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.382
# (0009, 1098) [PET norm_cal_id]                   UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.379
# (0009, 1099) [PET blnk_cal_id]                   UI: ''
# (0009, 109a) [PET cac_edge_threshold]            FL: 0.0
# (0009, 109b) [PET cac_skull_offset]              FL: 0.0
# (0009, 109c) [PET emiss_sub_id]                  UI: ''
# (0009, 109d) [PET radial_filter_3d]              SS: 0
# (0009, 109e) [PET radial_cutoff_3d]              FL: 0.0
# (0009, 109f) [PET axial_filter_3d]               SL: 0
# (0009, 10a0) [PET axial_cutoff_3d]               FL: 0.0
# (0009, 10a1) [PET axial_start]                   FL: 0.0
# (0009, 10a2) [PET axial_spacing]                 FL: 0.0
# (0009, 10a3) [PET axial_angles_used]             SL: 0
# (0009, 10a6) [PET slice_number]                  SL: 1
# (0009, 10a7) [PET total_counts]                  FL: 0.0
# (0009, 10ab) [PET bp_center_x]                   FL: -0.0
# (0009, 10ac) [PET bp_center_y]                   FL: 0.0
# (0009, 10ad) [PET trans_frame_id]                UI: ''
# (0009, 10ae) [PET tpluse_frame_id]               UI: ''
# (0009, 10b2) [PET ir_num_iterations]             SS: 2
# (0009, 10b3) [PET ir_num_subsets]                SS: 21
# (0009, 10b4) [PET ir_recon_fov]                  FL: 50.0
# (0009, 10b5) [PET ir_corr_model]                 SS: 0
# (0009, 10b6) [PET ir_loop_filter]                SS: 0
# (0009, 10b7) [PET ir_pre_filt_parm]              FL: 0.0
# (0009, 10b8) [PET ir_loop_filt_parm]             FL: 0.0
# (0009, 10b9) [PET response_filt_parm]            FL: 0.0
# (0009, 10ba) [PET post_filter]                   SS: 1
# (0009, 10bb) [PET post_filt_parm]                FL: 4.289999961853027
# (0009, 10bc) [PET ir_regularize]                 SS: 0
# (0009, 10bd) [PET regularize_parm]               FL: 0.0
# (0009, 10be) [PET ac_bp_filter]                  SS: 0
# (0009, 10bf) [PET ac_bp_filt_cut_off]            FL: 0.0
# (0009, 10c0) [PET ac_bp_filt_order]              SL: 0
# (0009, 10c1) [PET ac_img_smooth]                 SS: 0
# (0009, 10c2) [PET ac_img_smooth_parm]            FL: 0.0
# (0009, 10c3) [PET scatter_method]                SL: 0
# (0009, 10c4) [PET scatter_num_iter]              SS: 6
# (0009, 10c5) [PET scatter_parm]                  FL: 0.0
# (0009, 10c6) [PET seg_qc_parm]                   FL: 0.0
# (0009, 10c7) [PET overlap]                       SL: 0
# (0009, 10cb) [PET vqc_x_axis_trans]              FL: 0.8842740058898926
# (0009, 10cc) [PET vqc_x_axis_tilt]               FL: -0.026437999680638313
# (0009, 10cd) [PET vqc_y_axis_trans]              FL: -2.889328956604004
# (0009, 10ce) [PET vqc_y_axis_swivel]             FL: 0.03097900003194809
# (0009, 10cf) [PET vqc_z_axis_trans]              FL: 0.0
# (0009, 10d0) [PET vqc_z_axis_roll]               FL: 0.1664939969778061
# (0009, 10d5) [PET loop_filter_parm]              FL: 0.0
# (0009, 10d6) [PET image_one_loc]                 FL: 13.5
# (0009, 10d7) [PET image_index_loc]               FL: -1196.4000244140625
# (0009, 10d8) [PET frame_number]                  SL: 1
# (0009, 10db) [PET ir_z_filter_flag]              SL: 2
# (0009, 10dc) [PET ir_z_filter_ratio]             FL: 4.0
# (0009, 10df) [PET num_of_slices]                 US: 371
# (0009, 10e2) [PET rest_stress]                   SL: 10
# (0009, 10e4) [Recon Protocol]                    ST: '1_Torso_3D_AC_PET'
# (0009, 10e5) [PET left shift]                    FL: 0.0
# (0009, 10e6) [PET posterior shift]               FL: 0.0
# (0009, 10e7) [PET superior shift]                FL: 0.0
# (0009, 10e9) [PET acq_bin_dur_percent]           FL: 0.0
# (0009, 10ea) [3D Filter flag]                    SL: 0
# (0009, 10eb) [3D Filter cutoff]                  FL: 0.0
# (0009, 10ec) [3D Filter order]                   SL: 0
# (0010, 0000) Group Length                        UL: 90
# (0010, 0010) Patient's Name                      PN: 'LC00026'
# (0010, 0020) Patient ID                          LO: 'AW1367653740.410.1589332793'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 1020) Patient's Size                      DS: "1.72"
# (0010, 1030) Patient's Weight                    DS: "72.0"
# (0017, 0000) Private Creator                     UL: 46
# (0017, 0010) Private tag data                    LO: 'GEMS_PETD_01'
# (0017, 1004) [PET cal_datetime]                  DT: '20170927173654.00'
# (0018, 0000) Group Length                        UL: 236
# (0018, 0050) Slice Thickness                     DS: "3.27"
# (0018, 0071) Acquisition Termination Condition   CS: 'TIME'
# (0018, 0073) Acquisition Start Condition         CS: 'MANU'
# (0018, 0074) Acquisition Start Condition Data    IS: "0"
# (0018, 0075) Acquisition Termination Condition D IS: "0"
# (0018, 1020) Software Versions                   LO: '41.04'
# (0018, 1030) Protocol Name                       LO: 'Torso_PET/CT 3D'
# (0018, 1060) Trigger Time                        DS: "0.0"
# (0018, 1063) Frame Time                          DS: "0.0"
# (0018, 1083) Intervals Acquired                  IS: "0"
# (0018, 1084) Intervals Rejected                  IS: "0"
# (0018, 1100) Reconstruction Diameter             DS: "500.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1147) Field of View Shape                 CS: 'CYLINDRICAL RING'
# (0018, 1149) Field of View Dimension(s)          IS: [700, 153]
# (0018, 1181) Collimator Type                     CS: 'NONE'
# (0018, 1242) Actual Frame Duration               IS: "140000"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0000) Private Creator                     UL: 42
# (0019, 0010) Private tag data                    LO: 'GEMS_PETD_01'
# (0019, 1004) [PET cal_datetime]                  DT: '20161020184429'
# (0020, 0000) Group Length                        UL: 344
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.2.379.114374074503672.7872.1589332793459.4
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113619.2.379.114374074503672.7872.1589332794166.383
# (0020, 0010) Study ID                            SH: '77977679'
# (0020, 0011) Series Number                       IS: "4"
# (0020, 0013) Instance Number                     IS: "371"
# (0020, 0032) Image Position (Patient)            DS: [-248.04687500000, -248.04687500000, -1196.4000244140]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, -0]
# (0020, 0052) Frame of Reference UID              UI: 1.2.840.113619.2.379.114374074503672.7872.1589332793459.6
# (0020, 1040) Position Reference Indicator        LO: 'OM'
# (0020, 1041) Slice Location                      DS: "-1196.4"
# (0028, 0000) Group Length                        UL: 218
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 128
# (0028, 0011) Columns                             US: 128
# (0028, 0030) Pixel Spacing                       DS: [3.90625, 3.90625]
# (0028, 0051) Corrected Image                     CS: ['DECY', 'ATTN', 'SCAT', 'DTIM', 'RAN', 'DCAL', 'SLSENS', 'NORM']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0106) Smallest Image Pixel Value          SS: 0
# (0028, 0107) Largest Image Pixel Value           SS: 32767
# (0028, 1052) Rescale Intercept                   DS: "0.0"
# (0028, 1053) Rescale Slope                       DS: "0.479101"
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0040, 0555)  Acquisition Context Sequence  0 item(s) ----
# (0054, 0000) Group Length                        UL: 902
# (0054, 0013)  Energy Window Range Sequence  1 item(s) ----
#    (0054, 0014) Energy Window Lower Limit           DS: "375.0"
#    (0054, 0015) Energy Window Upper Limit           DS: "650.0"
#    ---------
# (0054, 0016)  Radiopharmaceutical Information Sequence  1 item(s) ----
#    (0018, 0031) Radiopharmaceutical                 LO: 'FDG -- fluorodeoxyglucose'
#    (0018, 1071) Radiopharmaceutical Volume          DS: "3.0"
#    (0018, 1072) Radiopharmaceutical Start Time      TM: '121600.00'
#    (0018, 1073) Radiopharmaceutical Stop Time       TM: '121700.00'
#    (0018, 1074) Radionuclide Total Dose             DS: "405509088.0"
#    (0018, 1075) Radionuclide Half Life              DS: "6588.0"
#    (0018, 1076) Radionuclide Positron Fraction      DS: "0.97000002861023"
#    (0018, 1078) Radiopharmaceutical Start DateTime  DT: '20200511121600.00'
#    (0018, 1079) Radiopharmaceutical Stop DateTime   DT: '20200511121700.00'
#    (0054, 0300)  Radionuclide Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C-111A1'
#       (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#       (0008, 0104) Code Meaning                        LO: '18F'
#       ---------
#    (0054, 0304)  Radiopharmaceutical Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C-B1031'
#       (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#       (0008, 0104) Code Meaning                        LO: 'FDG -- fluorodeoxyglucose'
#       ---------
#    ---------
# (0054, 0081) Number of Slices                    US: 371
# (0054, 0202) Type of Detector Motion             CS: 'NONE'
# (0054, 0410)  Patient Orientation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10450'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'recumbent'
#    ---------
# (0054, 0412)  Patient Orientation Modifier Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10340'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'supine'
#    ---------
# (0054, 0414)  Patient Gantry Relationship Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10470'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'headfirst'
#    ---------
# (0054, 1000) Series Type                         CS: ['STATIC', 'IMAGE']
# (0054, 1001) Units                               CS: 'BQML'
# (0054, 1002) Counts Source                       CS: 'EMISSION'
# (0054, 1100) Randoms Correction Method           CS: 'SING'
# (0054, 1101) Attenuation Correction Method       LO: 'measured,, 0.096000 cm-1,'
# (0054, 1102) Decay Correction                    CS: 'START'
# (0054, 1103) Reconstruction Method               LO: '3D IR'
# (0054, 1104) Detector Lines of Response Used     LO: '0'
# (0054, 1105) Scatter Correction Method           LO: 'Model Based'
# (0054, 1201) Axial Mash                          IS: [1, 2]
# (0054, 1202) Transverse Mash                     IS: "2"
# (0054, 1210) Coincidence Window Width            DS: "0.0"
# (0054, 1300) Frame Reference Time                DS: "0.0"
# (0054, 1310) Primary (Prompts) Counts Accumulate IS: "0"
# (0054, 1311) Secondary Counts Accumulated        IS: "0"
# (0054, 1320) Slice Sensitivity Factor            DS: "1.0"
# (0054, 1321) Decay Factor                        DS: "1.00738"
# (0054, 1322) Dose Calibration Factor             DS: "1718.0"
# (0054, 1323) Scatter Fraction Factor             DS: "0.392732"
# (0054, 1324) Dead Time Factor                    DS: "1.10327"
# (0054, 1330) Image Index                         US: 1
# (7fe0, 0010) Pixel Data                          OW: Array of 32768 elements
# 405509088.0
# 0 0.479101 0.00011815487652520876
# 0.0 1.8548782515943751

# %%
import matplotlib.pyplot as plt
for i in range(pet_nor.shape[0]):
    plt.imshow(pet_nor[i, :, :])
    plt.show()

# %%
pet_nor.min(), pet_nor.max()

# %%
x = 3**0.6
16*x**5 - 15*x**4 - 18*x**3 - 8*x**2 +18*x -9
